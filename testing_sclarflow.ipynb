# %%
from scalarflow.engine import value
from scalarflow.nn import network
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# getting dataset
from sklearn.datasets import make_moons
x, y = make_moons(noise=0.1)

print(f'x.shape: {x.shape}, y.shape: {y.shape}')
print(f'\nx: {x[:5]}, y: {y[:5]}')
plt.scatter(x[:,0], x[:,1], c=y)
# Out:
# x.shape: (100, 2), y.shape: (100,)
#
# x: [[ 0.38041275 -0.30824691]
#  [ 0.4497852   0.8370117 ]
#  [ 1.72738963 -0.39613597]
#  [-0.54824355  0.47195482]
#  [ 0.63987286 -0.33540584]], y: [1 0 1 0 1]

# %%
# initializing the model
model =  network(num_in=2, layer_sizes=[16, 16, 1], unit_activation='relu')

# %%
# model parameters
model.summary()
# Out:
# Network architecture:
# --------------------------------------
# neural network of 3 layers: [
# layer of 16 neurons: [
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu',
# neuron(weights: 2) - activation: 'Relu'],
# layer of 16 neurons: [
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu',
# neuron(weights: 16) - activation: 'Relu'],
# layer of 1 neurons: [
# neuron(weights: 16) - activation: 'Relu']
# ]
# --------------------------------------
# Total number of parameters: 337
# Total number of dense layers: 3
# Total number of neurons: 33
# Total number of weights: 34
# Total number of biases: 33

# %%
# training the model
model.fit(x, y, epochs=100)
# Out:
# Epoch: 1/100 - Loss: 0.8399
# Epoch: 11/100 - Loss: 0.5000
# Epoch: 21/100 - Loss: 0.5000
# Epoch: 31/100 - Loss: 0.5000
# Epoch: 41/100 - Loss: 0.5000
# Epoch: 51/100 - Loss: 0.5000
# Epoch: 61/100 - Loss: 0.5000
# Epoch: 71/100 - Loss: 0.5000
# Epoch: 81/100 - Loss: 0.5000
# Epoch: 91/100 - Loss: 0.5000
